# %%
import os
os.environ['OPENAI_API_KEY'] = '***'

# %%
import sys
sys.path.append('../')

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 
from prompt_nikuradse_p3 import SYS_MSG, IGNITE, ITER

#nikuradse data handles two things differently
#one is feedback loop
#other is scipy optimization, which is done 10 times, and the best based MAE is selected
from experiment import nikuradse

# %%
import pandas as pd

#Load selected data for LLM input
df = pd.read_csv("datasets/" + 'nikuradseM_36pts.csv')
data = df.to_dict(orient='list')
all_keys = list(data.keys())
all_values = list(data.values())
y = all_values[2]
x1 = all_values[0]
x2 = all_values[1]
dep_var = str(y)
indep_var = [str(x1), str(x2)]

#Load full data for SciPy optimization
df_O = pd.read_csv("datasets/" + 'nikuradse_modified.csv')
data_O = df_O.to_dict(orient='list')
all_keys_O = list(data_O.keys())
all_values_O = list(data_O.values())
y_O = all_values_O[2]
x1_O = all_values_O[0]
x2_O = all_values_O[1]
dep_var_O = str(y_O)
indep_var_O = [str(x1_O), str(x2_O)]


context = "The data is from an experiment that recorded turbulent friction in rough pipes with pipe roughness (x1) and Reynolds number (x2) as independent variables and turbulent friction (y) as the dependent variable."

# %%
import json 
N = 3
temp = 0.7
model = "gpt-4-0613"
total_iterations = 5
trim_every_iterations = 3
num_equations_to_keep = 5

sys_msg = SYS_MSG
ignite_msg=IGNITE
iter_msg = ITER

# Initialize an empty list to store the results
results_fromAllruns = []
iteration_infos_fromAllruns = []


for i in range(1):
    print(f"Running experiment {i+1}...")
    experiment = nikuradse(dep_var_O, indep_var_O, dep_var, indep_var, 
                           N, temp, context, 
                           sys_msg, ignite_msg, iter_msg,
                           model)
    
    CombResults, all_expressions, iteration_info, usage_list, total_chain_run_time, LLMrawExpressions = experiment.run(total_iterations, trim_every_iterations, num_equations_to_keep)
    
    results_fromAllruns.append({
        'CombResults': CombResults, 
        'all_expressions': all_expressions, 
        'usage_list': usage_list, 
        'total_chain_run_time': total_chain_run_time
    })
    
    # Store the iteration info
    iteration_infos_fromAllruns.append(iteration_info)

    print(f"Experiment {i+1} finished. Cost: {experiment.cost()}")

    directory_path = "tests/Nikuradse_P3S1"
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)  

    with open(f"{directory_path}/PromptsUsed.txt", 'w') as f:
        f.write(f"Sytstem Message: {SYS_MSG}\n")
        f.write(f"Starting Prompt: {IGNITE}\n")
        f.write(f"Iteration Prompt: {ITER}\n")

    with open(f"{directory_path}/run{i+1}.txt", 'w') as f:
        f.write("Final Results:\n")
        for result in json.loads(CombResults):
            json.dump(result, f, indent=2)
            f.write("\n")
        f.write(f"Cost for this run: ${experiment.cost()}\n")
        f.write(f"Total chain run time: {total_chain_run_time} seconds.\n")
        f.write(f"LLM-generated RawExpressions: {LLMrawExpressions} \n")
        f.write("\n\nIteration Information:\n")
        for info in iteration_info:
            json.dump(info, f, indent=2)
            f.write("\n")
# Out:
# Running experiment 1...
# Run 1: MAE = 0.25793867
# Run 2: MAE = 0.25793867
# Run 3: MAE = 0.25793867
# Run 4: MAE = 0.25793867
# Run 5: MAE = 0.25793867
# Run 6: MAE = 0.25793867
# Run 7: MAE = 0.25793867
# Run 8: MAE = 0.25793867
# Run 9: MAE = 0.25793867
# Run 10: MAE = 0.25793867
# Iteration:1
# SciPy feedback used for this iteration:
# [
#      {
#           "equation": "c[0]/x1",
#           "complexity": 3,
#           "mae": 0.25793867,
#           "mse": 0.07170147,
#           "fitted_params": [
#                14.537254111331155
#           ]
#      }
# ]
# LLM thoughts:
# Scratch Pad:
#
# Given the existing equation c[0]/x1 and its performance metrics, we can devise new equations by incorporating the second variable x2 and also by adding more complexity to the existing equation.
#
# As per the analysis of the dataset, it can be seen that the dependent variable 'y' is inversely proportional to 'x1'. This is evident from the equation c[0]/x1. Also, 'y' seems to have a non-linear relationship with 'x1' and 'x2'.
#
# We can incorporate 'x2' into the equation and also create equations with higher complexity to potentially improve the performance.
#
# Three potential equations that I could suggest are:
#
# 1. A simple addition of x2 to the existing equation which might capture any linear relationship between x2 and y.
# 2. A non-linear relationship of x1 and x2 by multiplying them together and taking the inverse.
# 3. A more complex equation involving both x1 and x2 with higher complexity, involving both addition and division operations.
# New equations generated:
# ['c[0]/x1+c[1]*x2', 'c[0]/(x1*x2)', '(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2']
# Run 1: MAE = 0.06146437
# Run 2: MAE = 0.06146437
# Run 3: MAE = 0.06146431
# Run 4: MAE = 0.06146431
# Run 5: MAE = 0.06146439
# Run 6: MAE = 0.06146448
# Run 7: MAE = 0.06146436
# Run 8: MAE = 0.06146435
# Run 9: MAE = 0.06146443
# Run 10: MAE = 0.06146442
# Run 1: MAE = 0.25937049
# Run 2: MAE = 0.25937049
# Run 3: MAE = 0.25937049
# Run 4: MAE = 0.25937049
# Run 5: MAE = 0.25937049
# Run 6: MAE = 0.25937049
# Run 7: MAE = 0.25937049
# Run 8: MAE = 0.25937049
# Run 9: MAE = 0.25937049
# Run 10: MAE = 0.25937049
# Run 1: MAE = 0.0597874
# Run 2: MAE = 0.0597874
# Run 3: MAE = 0.0597874
# Run 4: MAE = 0.0597874
# Run 5: MAE = 0.0597874
# Run 6: MAE = 0.0597874
# Run 7: MAE = 0.0597874
# Run 8: MAE = 0.0597874
# Run 9: MAE = 0.0597874
# Run 10: MAE = 0.0597874
# Iteration:2
# SciPy feedback used for this iteration:
# [
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.5368210493082455,
#          25.39472044929165,
#          0.07271388262655228
#       ]
#    },
#    {
#       "equation": "c[0]/x1+c[1]*x2",
#       "complexity": 7,
#       "mae": 0.06146431,
#       "mse": 0.00631077,
#       "fitted_params": [
#          6.971626385687687,
#          0.07163342640711798
#       ]
#    },
#    {
#       "equation": "c[0]/x1",
#       "complexity": 3,
#       "mae": 0.25793867,
#       "mse": 0.07170147,
#       "fitted_params": [
#          14.537254111331155
#       ]
#    },
#    {
#       "equation": "c[0]/(x1*x2)",
#       "complexity": 5,
#       "mae": 0.25937049,
#       "mse": 0.07814192,
#       "fitted_params": [
#          67.8446439558147
#       ]
#    }
# ]
# LLM thoughts:
# Scratch pad:
#
# Looking at the given data, it appears that the dependent variable 'y' is inversely proportional to 'x1' and directly proportional to 'x2'.
#
# From the Pareto front, we can see that the best equation so far has a complexity of 13 and an error (MAE) of approximately 0.059. This equation is "(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2".
#
# Given the restrictions, we can make new equations by combining the terms from the best equations and introducing division and multiplication to increase complexity while maintaining relevance to the problem.
#
# For example, we can combine terms from the best equation "(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2" and the second best equation "c[0]/x1+c[1]*x2" to form a new equation.
#
# We can also introduce division by 'x2' to the best equation to increase complexity and potentially improve accuracy.
#
# Finally, we can introduce multiplication of 'x1' and 'x2' in the denominator to increase complexity and potentially improve accuracy.
# New equations generated:
# ['(c[0]/x1)+(c[1]*x2)+(c[2]/(x1*x2))', '(c[0]/x1)+(c[1]/(x1*x2))+(c[2]/x2)', '(c[0]/(x1*x2))+(c[1]/x1)+(c[2]*x2)']
# Run 1: MAE = 0.0597874
# Run 2: MAE = 0.0597874
# Run 3: MAE = 0.0597874
# Run 4: MAE = 0.0597874
# Run 5: MAE = 0.0597874
# Run 6: MAE = 0.0597874
# Run 7: MAE = 0.0597874
# Run 8: MAE = 0.0597874
# Run 9: MAE = 0.0597874
# Run 10: MAE = 0.0597874
# Run 1: MAE = 0.04901088
# Run 2: MAE = 0.04901088
# Run 3: MAE = 0.04901088
# Run 4: MAE = 0.04901088
# Run 5: MAE = 0.04901088
# Run 6: MAE = 0.04901088
# Run 7: MAE = 0.04901088
# Run 8: MAE = 0.04901088
# Run 9: MAE = 0.04901088
# Run 10: MAE = 0.04901088
# Run 1: MAE = 0.0597874
# Run 2: MAE = 0.0597874
# Run 3: MAE = 0.0597874
# Run 4: MAE = 0.0597874
# Run 5: MAE = 0.0597874
# Run 6: MAE = 0.0597874
# Run 7: MAE = 0.0597874
# Run 8: MAE = 0.0597874
# Run 9: MAE = 0.0597874
# Run 10: MAE = 0.0597874
# Iteration:3
# SciPy feedback used for this iteration:
# [
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+(c[2]/x2)",
#       "complexity": 13,
#       "mae": 0.04901088,
#       "mse": 0.00340448,
#       "fitted_params": [
#          17.395994395218146,
#          -53.64830919075881,
#          1.8567467215948859
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.5368210493082455,
#          25.39472044929165,
#          0.07271388262655228
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]*x2)+(c[2]/(x1*x2))",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.536822562915219,
#          0.07271388333248455,
#          25.394710585789365
#       ]
#    },
#    {
#       "equation": "(c[0]/(x1*x2))+(c[1]/x1)+(c[2]*x2)",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          25.394734720358137,
#          1.5368177969100745,
#          0.0727138805275333
#       ]
#    },
#    {
#       "equation": "c[0]/x1+c[1]*x2",
#       "complexity": 7,
#       "mae": 0.06146431,
#       "mse": 0.00631077,
#       "fitted_params": [
#          6.971626385687687,
#          0.07163342640711798
#       ]
#    },
#    {
#       "equation": "c[0]/x1",
#       "complexity": 3,
#       "mae": 0.25793867,
#       "mse": 0.07170147,
#       "fitted_params": [
#          14.537254111331155
#       ]
#    },
#    {
#       "equation": "c[0]/(x1*x2)",
#       "complexity": 5,
#       "mae": 0.25937049,
#       "mse": 0.07814192,
#       "fitted_params": [
#          67.8446439558147
#       ]
#    }
# ]
# LLM thoughts:
# Scratch Pad:
#
# Looking at the Pareto front, it seems the most accurate equations have a complexity of 13, and the least complex (and least accurate) equations have complexities of 3 and 5. The equation with the lowest mean absolute error (MAE) is "(c[0]/x1)+(c[1]/(x1*x2))+(c[2]/x2)", with an MAE of 0.04901088.
#
# To generate diverse equations, I will consider different combinations of the variables x1 and x2 and the constants c[0], c[1], and c[2]. I will also consider different binary operators (+, -, *, / and ^). Since the data is from a turbulent friction experiment, the equations should ideally reflect the underlying physics of the problem. The Reynolds number is typically used to predict the onset of turbulence, and the pipe roughness can affect the friction coefficient.
#
# I'll start with shorter expressions, building on the best-performing short ones, and eventually propose longer expressions. I'll ensure that the proposed expressions are not SR-similar to avoid redundancy.
# New equations generated:
# ['(c[0]/(x1**2))+(c[1]/(x1*x2))+(c[2]/(x2**2))', '(c[0]*x1)+(c[1]/(x2**2))+(c[2]*x2)', '(c[0]/(x1*x2**2))+(c[1]*x1)+(c[2]/(x2*x1**2))']
# Run 1: MAE = 0.11357632
# Run 2: MAE = 0.11357632
# Run 3: MAE = 0.11357632
# Run 4: MAE = 0.11357632
# Run 5: MAE = 0.11357632
# Run 6: MAE = 0.11357632
# Run 7: MAE = 0.11357632
# Run 8: MAE = 0.11357632
# Run 9: MAE = 0.11357632
# Run 10: MAE = 0.11357632
# Run 1: MAE = 0.08275822
# Run 2: MAE = 0.08275826
# Run 3: MAE = 0.08275831
# Run 4: MAE = 0.08275825
# Run 5: MAE = 0.08275834
# Run 6: MAE = 0.08275826
# Run 7: MAE = 0.08275829
# Run 8: MAE = 0.08275825
# Run 9: MAE = 0.08275826
# Run 10: MAE = 0.08275818
# Run 1: MAE = 0.18604882
# Run 2: MAE = 0.18604882
# Run 3: MAE = 0.18604882
# Run 4: MAE = 0.18604882
# Run 5: MAE = 0.18604882
# Run 6: MAE = 0.18604882
# Run 7: MAE = 0.18604882
# Run 8: MAE = 0.18604882
# Run 9: MAE = 0.18604882
# Run 10: MAE = 0.18604882
# Iteration:4
# SciPy feedback used for this iteration:
# [
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+(c[2]/x2)",
#       "complexity": 13,
#       "mae": 0.04901088,
#       "mse": 0.00340448,
#       "fitted_params": [
#          17.395994395218146,
#          -53.64830919075881,
#          1.8567467215948859
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.5368210493082455,
#          25.39472044929165,
#          0.07271388262655228
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]*x2)+(c[2]/(x1*x2))",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.536822562915219,
#          0.07271388333248455,
#          25.394710585789365
#       ]
#    },
#    {
#       "equation": "(c[0]/(x1*x2))+(c[1]/x1)+(c[2]*x2)",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          25.394734720358137,
#          1.5368177969100745,
#          0.0727138805275333
#       ]
#    },
#    {
#       "equation": "c[0]/x1+c[1]*x2",
#       "complexity": 7,
#       "mae": 0.06146431,
#       "mse": 0.00631077,
#       "fitted_params": [
#          6.971626385687687,
#          0.07163342640711798
#       ]
#    }
# ]
# LLM thoughts:
# My analysis of the dataset:
#
# Looking at the given data and the previous model's predictions, it seems that equations involving the inverse of one or both independent variables (x1 and x2) perform better in terms of mean absolute error (MAE) and mean square error (MSE). These equations tend to be more complex, but that's expected given the non-linear nature of turbulent friction.
#
# From the equations provided, it seems that a combination of division and multiplication operations on the independent variables (x1 and x2) lead to better results. The constants (c[0], c[1], etc.) also seem to play a significant role in the overall quality of the predictions, with their values being particularly high or low depending on the equation.
#
# Given these observations, I will suggest new equations that use similar operations (division and multiplication) on the independent variables (x1 and x2), while also introducing a bit of diversity in terms of the structure of the equations to potentially capture different aspects of the data.
# New equations generated:
# ['c[0]/(x1*x2)+c[1]/x1+c[2]*x2+c[3]*x1', 'c[0]/(x1*x2)+c[1]/(x1**2)+c[2]*x2', '(c[0]/x1)*(c[1]/x2)+c[2]']
# Run 1: MAE = 0.0446922
# Run 2: MAE = 0.04469221
# Run 3: MAE = 0.0446922
# Run 4: MAE = 0.04469221
# Run 5: MAE = 0.04469221
# Run 6: MAE = 0.04469221
# Run 7: MAE = 0.0446922
# Run 8: MAE = 0.04469221
# Run 9: MAE = 0.04469221
# Run 10: MAE = 0.0446922
# Run 1: MAE = 0.0504906
# Run 2: MAE = 0.0504906
# Run 3: MAE = 0.0504906
# Run 4: MAE = 0.0504906
# Run 5: MAE = 0.0504906
# Run 6: MAE = 0.0504906
# Run 7: MAE = 0.0504906
# Run 8: MAE = 0.0504906
# Run 9: MAE = 0.0504906
# Run 10: MAE = 0.0504906
# Run 1: MAE = 0.05865059
# Run 2: MAE = 0.05865059
# Run 3: MAE = 0.05865059
# Run 4: MAE = 0.05865059
# Run 5: MAE = 0.05865059
# Run 6: MAE = 0.05865059
# Run 7: MAE = 0.05865059
# Run 8: MAE = 0.05865059
# Run 9: MAE = 0.05865059
# Run 10: MAE = 0.05865059
# Iteration:5
# SciPy feedback used for this iteration:
# [
#    {
#       "equation": "c[0]/(x1*x2)+c[1]/x1+c[2]*x2+c[3]*x1",
#       "complexity": 17,
#       "mae": 0.0446922,
#       "mse": 0.00400164,
#       "fitted_params": [
#          33.99514841234556,
#          -1.6989691262181155,
#          0.08920545190177598,
#          -0.00034269825331926813
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+(c[2]/x2)",
#       "complexity": 13,
#       "mae": 0.04901088,
#       "mse": 0.00340448,
#       "fitted_params": [
#          17.395994395218146,
#          -53.64830919075881,
#          1.8567467215948859
#       ]
#    },
#    {
#       "equation": "c[0]/(x1*x2)+c[1]/(x1**2)+c[2]*x2",
#       "complexity": 15,
#       "mae": 0.0504906,
#       "mse": 0.00452291,
#       "fitted_params": [
#          53.55395004621771,
#          -67.98838652720801,
#          0.06753599143612574
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)*(c[1]/x2)+c[2]",
#       "complexity": 9,
#       "mae": 0.05865059,
#       "mse": 0.00510235,
#       "fitted_params": [
#          72605657.07799995,
#          3.980672917547579e-07,
#          0.38523378124301727
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]/(x1*x2))+c[2]*x2",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.5368210493082455,
#          25.39472044929165,
#          0.07271388262655228
#       ]
#    },
#    {
#       "equation": "(c[0]/x1)+(c[1]*x2)+(c[2]/(x1*x2))",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          1.536822562915219,
#          0.07271388333248455,
#          25.394710585789365
#       ]
#    },
#    {
#       "equation": "(c[0]/(x1*x2))+(c[1]/x1)+(c[2]*x2)",
#       "complexity": 13,
#       "mae": 0.0597874,
#       "mse": 0.00578242,
#       "fitted_params": [
#          25.394734720358137,
#          1.5368177969100745,
#          0.0727138805275333
#       ]
#    },
#    {
#       "equation": "c[0]/x1+c[1]*x2",
#       "complexity": 7,
#       "mae": 0.06146431,
#       "mse": 0.00631077,
#       "fitted_params": [
#          6.971626385687687,
#          0.07163342640711798
#       ]
#    }
# ]
# LLM thoughts:
# Scratch Pad:
#
# Looking at the provided list of equations, it's evident that the division operation (/) is a recurring pattern. It seems the relationship between the dependent variable and the independent variables is inversely proportional. Furthermore, the multiplication of the independent variables, either in direct form (x1*x2) or in a reciprocal form (1/(x1*x2)), is also frequent.
#
# The complexity of the equations varies from as low as 7 to as high as 17. For lower complexity, the Mean Absolute Error (MAE) tends to be higher, indicating a trade-off between complexity and accuracy.
#
# The equation with the lowest MAE (0.0446922) and highest complexity (17) is "c[0]/(x1*x2)+c[1]/x1+c[2]*x2+c[3]*x1". This equation involves all the binary operations except for the power operation (^).
#
# Considering the restrictions and the aim to achieve a lower MAE with a reasonable complexity, I will suggest new equations based on the patterns observed in the dataset and the existing equations.
#
# I will avoid suggesting SR-similar expressions to prevent redundancy.
# New equations generated:
# ['c[0]/(x1*x2)+c[1]/(x1**2)+c[2]*x2+c[3]*x1', 'c[0]/(x1*x2)+c[1]*(x1/x2)+c[2]/x1+c[3]*x2', 'c[0]/(x1*x2)+c[1]/(x2**2)+c[2]*x1+c[3]*x2']
# Run 1: MAE = 0.04047852
# Run 2: MAE = 0.04047851
# Run 3: MAE = 0.04047851
# Run 4: MAE = 0.04047852
# Run 5: MAE = 0.04047851
# Run 6: MAE = 0.04047851
# Run 7: MAE = 0.04047852
# Run 8: MAE = 0.04047852
# Run 9: MAE = 0.04047851
# Run 10: MAE = 0.04047852
# Run 1: MAE = 0.05008763
# Run 2: MAE = 0.05008764
# Run 3: MAE = 0.05008764
# Run 4: MAE = 0.05008764
# Run 5: MAE = 0.05008764
# Run 6: MAE = 0.05008763
# Run 7: MAE = 0.05008764
# Run 8: MAE = 0.05008764
# Run 9: MAE = 0.05008764
# Run 10: MAE = 0.05008763
# Run 1: MAE = 0.03834216
# Run 2: MAE = 0.03834215
# Run 3: MAE = 0.0383421
# Run 4: MAE = 0.0383421
# Run 5: MAE = 0.0383421
# Run 6: MAE = 0.03834214
# Run 7: MAE = 0.03834213
# Run 8: MAE = 0.03834209
# Run 9: MAE = 0.0383421
# Run 10: MAE = 0.03834212
# Run 1: MAE = 0.04047852
# Run 2: MAE = 0.04047851
# Run 3: MAE = 0.04047851
# Run 4: MAE = 0.04047851
# Run 5: MAE = 0.04047852
# Run 6: MAE = 0.04047851
# Run 7: MAE = 0.04047851
# Run 8: MAE = 0.04047852
# Run 9: MAE = 0.04047851
# Run 10: MAE = 0.04047851
# Run 1: MAE = 0.05008764
# Run 2: MAE = 0.05008764
# Run 3: MAE = 0.05008763
# Run 4: MAE = 0.05008764
# Run 5: MAE = 0.05008764
# Run 6: MAE = 0.05008764
# Run 7: MAE = 0.05008763
# Run 8: MAE = 0.05008764
# Run 9: MAE = 0.05008763
# Run 10: MAE = 0.05008764
# Run 1: MAE = 0.03834208
# Run 2: MAE = 0.03834212
# Run 3: MAE = 0.03834214
# Run 4: MAE = 0.03834213
# Run 5: MAE = 0.03834212
# Run 6: MAE = 0.03834213
# Run 7: MAE = 0.03834214
# Run 8: MAE = 0.03834213
# Run 9: MAE = 0.0383421
# Run 10: MAE = 0.0383421
# Experiment 1 finished. Cost: 0.36452999999999997
